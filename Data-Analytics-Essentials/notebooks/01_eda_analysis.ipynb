# %% [markdown]
# # Real Estate Market Analysis
#
# ## Project Goal
# Perform an end-to-end Exploratory Data Analysis (EDA) on a real-estate dataset and generate business insights.

# %% [markdown]
# ## Analytics Workflow
#
# Business Question → Data Understanding → Cleaning → Visualization → Insights → Recommendation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/real_estate_dataset.csv')
df.head()

# %% [markdown]
# ## Dataset Overview

# %%
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])
df.info()

# %% [markdown]
# ## Missing Values Analysis

# %%
df.isnull().sum()

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe(include='all')

# %% [markdown]
# ## Distribution Analysis

# %%
numeric_cols = df.select_dtypes(include='number').columns
numeric_cols

# %%
for col in numeric_cols[:4]:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Business Insights Template
#
# Use the analysis above to answer:
#
# 1. Which variables influence price the most?
# 2. Are there noticeable outliers?
# 3. Which property types appear most valuable?
# 4. What recommendations would you provide to management?

# %% [markdown]
# ## Executive Summary
#
# Write 3-5 business insights and recommendations here.
